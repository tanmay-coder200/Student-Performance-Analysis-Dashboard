# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (2.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Tulsi\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Tulsi\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Tulsi\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\tulsi\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\Tulsi\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student-por.csv')

# %%
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# 1  ...      5        3      3     1     1      3        2   9  11  11
# 2  ...      4        3      2     2     3      3        6  12  13  12
# 3  ...      3        2      2     1     1      5        0  14  14  14
# 4  ...      4        3      2     1     2      5        0  11  13  13
# 5  ...      5        4      2     1     2      5        6  12  12  13
# 6  ...      4        4      4     1     1      3        0  13  12  13
# 7  ...      4        1      4     1     1      1        2  10  13  13
# 8  ...      4        2      2     1     1      1        0  15  16  17
# 9  ...      5        5      1     1     1      5        0  12  12  13
#
# [10 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
df_new = df.copy()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 corr = df.corr()
#       2 sns.heatmap(corr, annot=True, cmap='coolwarm')
#       3 plt.show()
#
# File c:\Users\Tulsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Tulsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\Tulsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\Tulsi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'GP'

# %%
corr_matrix = df_new.select_dtypes(include=['int64', 'float64']).corr()

print(corr_matrix)
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# absences    0.149998 -0.008577  0.029859   -0.008149  -0.118389  0.122779
# G1         -0.174322  0.260472  0.217501   -0.154120   0.260875 -0.384210
# G2         -0.107119  0.264035  0.225139   -0.154489   0.240498 -0.385782
# G3         -0.106505  0.240151  0.211800   -0.127173   0.249789 -0.393316
#
#               famrel  freetime     goout      Dalc      Walc    health  \
# age        -0.020559 -0.004910  0.112805  0.134768  0.086357 -0.008750
# Medu        0.024421 -0.019686  0.009536 -0.007018 -0.019766  0.004614
# Fedu        0.020256  0.006841  0.027690  0.000061  0.038445  0.044910
# traveltime -0.009521  0.000937  0.057454  0.092824  0.057007 -0.048261
# studytime  -0.004127 -0.068829 -0.075442 -0.137585 -0.214925 -0.056433
# failures   -0.062645  0.108995  0.045078  0.105949  0.082266  0.035588
# famrel      1.000000  0.129216  0.089707 -0.075767 -0.093511  0.109559
# freetime    0.129216  1.000000  0.346352  0.109904  0.120244  0.084526
# goout       0.089707  0.346352  1.000000  0.245126  0.388680 -0.015741
# Dalc       -0.075767  0.109904  0.245126  1.000000  0.616561  0.059067
# Walc       -0.093511  0.120244  0.388680  0.616561  1.000000  0.114988
# health      0.109559  0.084526 -0.015741  0.059067  0.114988  1.000000
# absences   -0.089534 -0.018716  0.085374  0.172952  0.156373 -0.030235
# G1          0.048795 -0.094497 -0.074053 -0.195171 -0.155649 -0.051647
# G2          0.089588 -0.106678 -0.079469 -0.189480 -0.164852 -0.082179
# G3          0.063361 -0.122705 -0.087641 -0.204719 -0.176619 -0.098851
#
#             absences        G1        G2        G3
# age         0.149998 -0.174322 -0.107119 -0.106505
# Medu       -0.008577  0.260472  0.264035  0.240151
# Fedu        0.029859  0.217501  0.225139  0.211800
# traveltime -0.008149 -0.154120 -0.154489 -0.127173
# studytime  -0.118389  0.260875  0.240498  0.249789
# failures    0.122779 -0.384210 -0.385782 -0.393316
# famrel     -0.089534  0.048795  0.089588  0.063361
# freetime   -0.018716 -0.094497 -0.106678 -0.122705
# goout       0.085374 -0.074053 -0.079469 -0.087641
# Dalc        0.172952 -0.195171 -0.189480 -0.204719
# Walc        0.156373 -0.155649 -0.164852 -0.176619
# health     -0.030235 -0.051647 -0.082179 -0.098851
# absences    1.000000 -0.147149 -0.124745 -0.091379
# G1         -0.147149  1.000000  0.864982  0.826387
# G2         -0.124745  0.864982  1.000000  0.918548
# G3         -0.091379  0.826387  0.918548  1.000000
